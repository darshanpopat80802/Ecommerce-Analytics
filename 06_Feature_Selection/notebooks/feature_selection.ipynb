# %% [markdown]
# <h1>Feature Engineering - Ecommerce Platform</h1>

# %% [markdown]
# <h4>Step 1: Missing Value Treatment</h4>
#
# <h4>Techniques</h4>
#
# <li>Complete Case Analysis (CCA)</li>
# <li>SimpleImputer</li>
# <ul>
# <li>Mean</li>
# <li>Median</li>
# <li>Mode</li>
# <li>Constant</li>
# </ul>
# <li>KNN Imputer</li>
# <li>Iterative Imputer (MICE)</li>
# <li>Missing Indicator</li>

# %% [markdown]
# <h4>Step 2: Categorical Feature Encoding</h4>
#
# <h4>Techniques</h4>
#
# <li>OrdinalEncoder
# <li>OneHotEncoder
# <li>LabelEncoder (Target Variable)
#
# <h4>Questions</h4>
#
# <li>Ordered categories?</li>
# <li>Unordered categories?</li>
# <li>Target encoding required?</li>

# %% [markdown]
# <h4>Step 3: Numerical Feature Transformation</h4>
#
# <h4>FunctionTransformer</h4>
# <li>Log Transformation</li>
# <li>Square Root Transformation</li>
# <li>Reciprocal Transformation</li>
# <li>Custom Transformation</li>
#
# <h4>PowerTransformer</h4>
# <li>Box-Cox</li>
# <li>Yeo-Johnson</li>
#
# <h4>Purpose</h4>
# <li>Reduce skewness</li>
# <li>Improve normality</li>
# <li>Improve model assumptions</li>

# %% [markdown]
# <h4>Step 4: Outlier Treatment</h4>
#
# <h4>Techniques</h4>
#
# <li>IQR Method</li>
# <li>Z-Score Method</li>
# <li>Winsorization</li>
# <li>Capping</li>
#
# <h4>Questions</h4>
#
# <li>Remove?</li>
# <li>Cap?</li>
# <li>Transform?</li>

# %% [markdown]
# <h4>Step 5: Feature Scaling</h4>
#
# <h4>Techniques</h4>
#
# <li>StandardScaler</li>
# <li>MinMaxScaler</li>
# <li>RobustScaler</li>
# <li>MaxAbsScaler</li>
#
# <h4>Questions</h4>
#
# <li>Outliers present?</li>
# <li>Fixed range required?</li>
# <li>Normal distribution?</li>

# %% [markdown]
# <h4>Step 6: Multiple Column Transformations</h4>
#
# <h4>Tools</h4>
#
# <li>ColumnTransformer</li>
# <li>Pipeline</li>

# %% [markdown]
# <h4>Step 7: Feature Construction --> Create new features</h4>
#
# <h4>Examples</h4>
#
# <li>Age from DOB</li>
# <li>Revenue per Customer</li>
# <li>Profit Margin</li>
# <li>Month from Date</li>
# <li>Quarter from Date</li>
# <li>Customer Tenure</li>

# %% [markdown]
# <h4>Step 8: Feature Validation</h4>
#
# <h4>Verify</h4>
#
# <li>No missing values</li>
# <li>No invalid categories</li>
# <li>Correct dimensions</li>
# <li>Correct scaling</li>
# <li>Correct transformations</li>

# %% [markdown]
# <h4>Step 9: Feature Engineering Summary</h4>
#
# <h4>Document</h4>
#
# <li>Features Added</li>
# <li>Features Removed</li>
# <li>Transformations Applied</li>
# <li>Encodings Applied</li>
# <li>Scaling Applied</li>
