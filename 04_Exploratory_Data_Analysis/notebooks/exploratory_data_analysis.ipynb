# %% [markdown]
# <h1>EDA - Ecommerce Platform</h1>

# %% [markdown]
# <h4>Step 1: Column Classification</h4>
# <li>Numerical Columns</li>
# <li>Categorical Columns</li>
# <li>Datetime Columns</li>
# <li>Target Column</li>
# <li>Identifier Columns</li>

# %% [markdown]
# <h4>Step 2: Univariate Analysis</h4>
# <li>Descriptive Statistics</li>
# <li>Visualisation</li>
# <li>Identifying Outliers</li>
# <li>Skewness</li>
# <li>Conclusion</li>
#
# <h4>Deliverables</h4>
# <li>Histograms</li>
# <li>Boxplots</li>
# <li>Value Counts</li>

# %% [markdown]
# <h4>Step 3: Bivariate Analysis</h4>
# <li>Select 2 Columns --> Understand Type of Relationship</li>
# <li>Numerical - Numerical</li>
# <li>Numerical - Categorical</li>
# <li>Categorical - Categorical</li>
#
# <h4>Questions</h4>
#
# <li>Which variables influence the target?</li>
# <li>Which variables move together?</li>
# <li>Are there strong correlations?</li>

# %% [markdown]
# <h4>Step 4: Multivariate Analysis</h4>
# <li>Select Multiple Columns</li>
# <li>Understand Types of Relationship</li>
# <li>Visualisation</li>
# <li>Conclusion</li>
#
# <h4>Techniques</h4>
#
# <li>Correlation Matrix</li>
# <li>Pairplots</li>
# <li>Pivot Tables</li>
# <li>Group Analysis</li>
#
# <h4>Questions</h4>
#
# <li>Which variables interact together?</li>
# <li>Which combinations affect the target?</li>

# %% [markdown]
# <h4>Step 5: Feature Engineering Opportunities</h4>
#
# <h4>Identify possible transformations</h4>
#
# <li>Missing Value Strategies</li>
# <li>Encoding Requirements</li>
# <li>Scaling Requirements</li>
# <li>Date Feature Creation</li>
# <li>Binning Opportunities</li>
# <li>Interaction Features</li>
# <li>Aggregation Features</li>
# <li>Log Transformations</li>
# <li>Power Transformations</li>
