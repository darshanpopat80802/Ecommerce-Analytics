# %% [markdown]
# <h1>Final Model Selection - Ecommerce Platform</h1>

# %% [markdown]
# <h4>Step 6: Save Selected Model</h4>
#
# <h4>Store</h4>
#
# <li>Model Object</li>
# <li>Configuration</li>
# <li>Parameters</li>

# %% [markdown]
# <h4>Step 7: Document Modeling Decisions</h4>
#
# <h4>Record</h4>
#
# <li>Models Tested</li>
# <li>Models Rejected</li>
# <li>Selection Reason</li>
# <li>Business Justification</li>
