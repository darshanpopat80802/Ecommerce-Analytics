# %% [markdown]
# <h1>Model Comparison - Ecommerce Platform</h1>

# %% [markdown]
# <h4>Step 3: Model Comparison</h4>
#
# <h4>Compare model performance</h4>
#
# <h4>Classification Metrics</h4>
#
# <li>Accuracy</li>
# <li>Precision</li>
# <li>Recall</li>
# <li>F1 Score</li>
# <li>ROC-AUC</li>
#
# <h4>Regression Metrics</h4>
#
# <li>MAE</li>
# <li>MSE</li>
# <li>RMSE</li>
# <li>R²</li>

# %% [markdown]
# <h4>Step 4: Analyze Overfitting</h4>
#
# <h4>Compare</h4>
#
# <h4>Training Performance vs Validation Performance</h4>
#
# <h4>Questions</h4>
#
# <li>Underfitting?</li>
# <li>Overfitting?</li>
# <li>Balanced Performance?</li>

# %% [markdown]
# <h4>Step 5: Select Best Candidate</h4>
#
# <h4>Selection Criteria</h4>
#
# <li>Metric Performance</li>
# <li>Stability</li>
# <li>Training Time</li>
# <li>Interpretability</li>
# <li>Business Requirements</li>
