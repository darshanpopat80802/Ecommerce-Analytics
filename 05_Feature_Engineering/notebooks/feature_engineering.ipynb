# %% [markdown]
# <h1>Feature Selection - Ecommerce Platform</h1>

# %% [markdown]
# <h4>Step 1: Initial Feature Review</h4>
#
# <h4>Review</h4>
#
# <li>Identifier Columns</li>
# <li>Constant Columns</li>
# <li>Near Constant Columns</li>
# <li>Duplicate Features</li>
# <li>Highly Correlated Features</li>
#
# <h4>Remove unnecessary features</h4>

# %% [markdown]
# <h4>Step 2: Filter Methods</h4>
#
# <h4>Techniques</h4>
#
# <h4>For Numerical Features</h4>
#
# <li>Correlation Analysis</li>
# <li>Variance Threshold</li>
#
# <h4>For Categorical Features</h4>
#
# <li>Chi-Square Test</li>
# <li>ANOVA Test</li>
# <li>Mutual Information</li>

# %% [markdown]
# <h4>Step 3: Wrapper Methods</h4>
#
# <h4>Techniques</h4>
#
# <li>Forward Selection</li>
# <li>Backward Elimination</li>
# <li>Recursive Feature Elimination (RFE)</li>
#
# <h4>Purpose</h4>
#
# <li>Evaluate feature subsets using model performance</li>

# %% [markdown]
# <h4>Step 4: Embedded Methods</h4>
#
# <h4>Techniques</h4>
#
# <li>Lasso Regression (L1)</li>
# <li>Ridge Regression</li>
# <li>ElasticNet</li>
# <li>Random Forest Feature Importance</li>
# <li>XGBoost Feature Importance</li>
#
# <h4>Purpose</h4>
#
# <li>Allow the model itself to determine feature importance.</li>

# %% [markdown]
# <h4>Step 5: Feature Importance Analysis</h4>
#
# <h4>Generate ranking of all features</h4>
#
# <h4>Questions</h4>
#
# <li>Most important features?</li>
# <li>Least important features?</li>
# <li>Features contributing to target prediction?</li>

# %% [markdown]
# <h4>Step 6: Final Feature Selection</h4>
#
# <h4>Create final list</h4>
#
# <h4>Selected Features</h4>
#
# <h4>Rejected Features</h4>
#
# <h4>Document reasons for removal</h4>
#
# <h4>Examples</h4>
#
# <li>Low Variance</li>
# <li>High Correlation</li>
# <li>Low Importance</li>
# <li>Business Irrelevance</li>
