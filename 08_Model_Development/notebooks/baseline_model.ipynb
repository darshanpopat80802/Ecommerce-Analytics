# %% [markdown]
# <h1>Baseline Model - Ecommerce Platform</h1>

# %% [markdown]
# <h4>Step 1: Establish Baseline Model</h4>
#
# <h4>Purpose</h4>
#
# <li>Create a simple benchmark model</li>
#
# <h4>Examples</h4>
#
# <h4>Classification</h4>
#
# <li>Logistic Regression</li>
# <li>Decision Tree</li>
#
# <h4>Regression</h4>
#
# <li>Linear Regression</li>
# <li>Decision Tree Regressor</li>

# %% [markdown]
# <h4>Step 2: Candidate Model Training</h4>
#
# <h4>Train multiple models</h4>
#
# <h4>Classification Examples</h4>
#
# <li>Logistic Regression</li>
# <li>KNN</li>
# <li>Decision Tree</li>
# <li>Random Forest</li>
# <li>SVM</li>
# <li>XGBoost</li>
# <li>LightGBM</li>
# <li>CatBoost</li>
#
# <h4>Regression Examples</h4>
#
# <li>Linear Regression</li>
# <li>Ridge</li>
# <li>Lasso</li>
# <li>Decision Tree</li>
# <li>Random Forest</li>
# <li>XGBoost</li>
# <li>LightGBM</li>
# <li>CatBoost</li>
#
# <h4>Document all experiments</h4>
