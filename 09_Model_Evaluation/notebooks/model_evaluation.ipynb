# %% [markdown]
# <h1>Model Evaluation - Ecommerce Platform</h1>

# %% [markdown]
# <h4>Step 1: Evaluate on Test Dataset</h4>
#
# <h4>Use data never seen during training</h4>
#
# <h4>Purpose</h4>
#
# <li>Measure true generalization performance</li>

# %% [markdown]
# <h4>Step 2: Classification Metrics</h4>
#
# <h4>Applicable for Classification Problems</h4>
#
# <h4>Metrics</h4>
#
# <li>Accuracy</li>
# <li>Precision</li>
# <li>Recall</li>
# <li>F1 Score</li>
# <li>ROC-AUC</li>
# <li>Log Loss</li>

# %% [markdown]
# <h4>Step 3: Regression Metrics</h4>
#
# <h4>Applicable for Regression Problems</h4>
#
# <h4>Metrics</h4>
#
# <li>MAE</li>
# <li>MSE</li>
# <li>RMSE</li>
# <li>R² Score</li>
# <li>Adjusted R²</li>

# %% [markdown]
# <h4>Step 4: Confusion Matrix Analysis</h4>
#
# <h4>Classification Only</h4>
#
# <h4>Analyse</h4>
#
# <li>True Positives</li>
# <li>True Negatives</li>
# <li>False Positives</li>
# <li>False Negatives</li>
#
# <h4>Questions</h4>
#
# <li>What mistakes is the model making?</li>
# <li>Which class is most problematic?</li>

# %% [markdown]
# <h4>Step 5: ROC-AUC Analysis</h4>
#
# <h4>Classification Only</h4>
#
# <h4>Evaluate</h4>
#
# <li>ROC Curve</li>
# <li>AUC Score</li>
#
# <h4>Purpose</h4>
#
# <li>Understand model discrimination capability</li>
